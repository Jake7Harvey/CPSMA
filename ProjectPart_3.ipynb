# %% [markdown]
# <a href="https://colab.research.google.com/github/Jake7Harvey/CPSMA/blob/main/ProjectPart_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Module #3: CPSMA-3913-01
# ##Dr Matthew Lynam
# ###Probability
# ###Jake Harvey 0273045

# %% [markdown]
# ![Pro3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ###1.) Create your own sample space, compute probabilities and simulate selecting items from it.

# %% [markdown]
# ####A.)Create a sample space with three or more simple events. Assign a probability to each item. Show that the axioms of probability hold under this assignment.

# %% [markdown]
# ***Cards*** are one of the easiest ways to show probabilities, **52** total *(excluding Jokers)*, **4** ***suits***, **4** ***aces***, **4** of each number from **2** to **10**, **4** ***Jacks***, **4** ***Queens***, and **4** ***Kings***.
#
# **Keeping things simple I will first start with the suits**
#
# ***Diamonds*** take up 13 cards out of the full 52 totaling 25% or 0.25.
#
# ***Spades*** take up 13 cards out of the full 52 totaling 25% or 0.25.
#
# ***Hearts*** take up 13 cards out of the full 52 totaling 25% or 0.25.
#
# ***Clubs*** take up 13 cards out of the full 52 totaling 25% or 0.25.

# %%
probaility = [1/4,1/4,1/4,1/4]
sum(probaility)
# Out:
# 1.0

# %% [markdown]
# ####B.)Create a compound event that uses some of the simple events.

# %% [markdown]
# Compound Events are events when more than one thing happens at a time, like drawing two aces in a row without replacing the first one.
#
# P(ace1)=4/52
#
# P(ace2)=3/51

# %%
probability=[(4/52*3/51)]
sum(probability)
# Out:
# 0.004524886877828055

# %% [markdown]
# The probability of drawing two ***aces*** in a row without replacement is **0.004524886877828055** or  **<sup>1</sup>/<sub>221</sub>**

# %% [markdown]
# ####C.)Compute the probability of a union and an intersection of your events.

# %% [markdown]
# Unions can be described as getting a Diamond and a Jack or a Jack of Diamonds.
#
# P(diamond)=13/52
#
# p(jack)=4/52
#
# p(jackofdiamonds)=1/52

# %%
probability=[(13/52+4/52)-(1/52)]
sum(probability)
# Out:
# 0.3076923076923077

# %% [markdown]
# The pobability of drawing a **Diamond** and a **Jack** or a **Jack of Diamonds** is **0.3076923076923077** or **<sup>4</sup>/<sub>13</sub>**

# %% [markdown]
# Intersections can be described as drawing a red ace from a full deck.
#
# P(red)=26/52
#
# p(ace)=4/52

# %%
probability=[26/52*4/52]
sum(probability)
# Out:
# 0.038461538461538464

# %% [markdown]
# The pobability of drawing a **Red Ace** is **0.038461538461538464** or **<sup>1</sup>/<sub>26</sub>**

# %% [markdown]
# ####D.)Compute both conditional probabilities of two events. Make sure to explain what they are in words. Apply Bayes’ theorem to verify your result.

# %% [markdown]
# Conditional probabilities are the odds of one event happening after another event has already occured, like drawing a king and if it was known that is was a club.
#
# p(king)=4/52
#
# p(kingofclubs)=1/52

# %%
probability=[(1/52) / (4/52)]
sum(probability)
# Out:
# 0.25

# %% [markdown]
# ***Verification***

# %%
bayes=[(13/52 * 0.07692307692307693) / (4/52)]
sum(bayes)
# Out:
# 0.25

# %% [markdown]
# P(diamond)=13/52
#
#
# p(jackofdiamonds)=1/52

# %%
probability=[(1/52) / (13/52)]
sum(probability)
# Out:
# 0.07692307692307693

# %% [markdown]
# ***Verification***

# %%
bayes=[(4/52 * 0.25) / (13/52)]
sum(bayes)
# Out:
# 0.07692307692307693

# %% [markdown]
# ####E.)Compute the probability of the complement of an event.

# %% [markdown]
# Complements are the probability of something to not happen, like not Diamond and a Jack or a Jack of Diamonds.

# %%
notlikely=[1-0.3076923076923077]
sum(notlikely)
# Out:
# 0.6923076923076923

# %% [markdown]
# The probability of not drawing **Diamond** and a **Jack** or a **Jack of Diamonds** is **0.6923076923076923** or **<sup>9</sup>/<sub>13</sub>**

# %% [markdown]
# ####F.) Simulate a simple occurrence of your sample space 10 times. Pick an event, does the simulation give you exactly the same probability as your assignment? Explain why or why not.

# %%
from random import choices
choices(['Diamonds','Spades','Hearts','Clubs'],k=10)
# Out:
# ['Spades',
#  'Spades',
#  'Spades',
#  'Hearts',
#  'Diamonds',
#  'Diamonds',
#  'Clubs',
#  'Diamonds',
#  'Spades',
#  'Clubs']

# %% [markdown]
#  The simulation does not give me exactly the same probability as my assignment, because it is not the right amount for the number of outcomes to match the assignment. Anything divisible by 4 has a better chance of working.

# %% [markdown]
# ###2.)

# %% [markdown]
# I discoverd in this project that probabilities are used everyday without showing them. Coding was not to bad for this project once I got the hang of it, but I do wish that my formatting was better. I believe that simulation might be different from ideal sample space because it is true random, unlike the way we would like things to fall due to bias or other reasons.
