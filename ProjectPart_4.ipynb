# %% [markdown]
# <a href="https://colab.research.google.com/github/Jake7Harvey/CPSMA/blob/main/ProjectPart_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Module #3: CPSMA-3913-01
# ##Dr Matthew Lynam
# ###Counting
# ###Jake Harvey 0273045

# %% [markdown]
# ![Pro4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# I believe that cards will be the easiest way to describe counting, and so I will be using cards for this project

# %% [markdown]
# ##1. Consider a simulation of 10 events with 20 possible outcomes.

# %%
possibleChoices = ['Clubs','Diamonds','Hearts','Spades']

# %% [markdown]
# ###(a) How many outcomes were possible in your simulation if it is considered a sequence in that particular order?

# %% [markdown]
# There are four different suits in cards, minus the **Jokers**, and so for each event there is a chance that one of those four suits will be drawn
#
# The number of possibilities will be $4^{10}$

# %% [markdown]
# ###(b) How many outcomes were possible in your simulation if order did not matter?

# %% [markdown]
# If order does not matter for the outcomes, then the equation is:
#
# $4^{10} = 1048575$
#
# There is a total of 1048575 different outcomes!

# %%
4**10
# Out:
# 1048576

# %% [markdown]
# ###(c) How many outcomes were possible if you were not allowed to select an item multiple times.. Give two answers, with order mattering and not.

# %% [markdown]
# $$
# \binom{n+k-1}{k-1} = \binom{n+k-1}{n}
# $$

# %% [markdown]
# ###Order Matters
# ###With Replacement

# %%
import math
math.factorial(13)/(math.factorial(10)*math.factorial(3))
# Out:
# 286.0

# %% [markdown]
# My logic might be wrong, but I used 13 becasue 4-1=3+10=13

# %%
from itertools import combinations_with_replacement
print(list(combinations_with_replacement(possibleChoices,10)))
# Out:
# [('Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs'), ('Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Diamonds'), ('Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Hearts'), ('Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Spades'), ('Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Diamonds', 'Diamonds'), ('Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Diamonds', 'Hearts'), ('Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Diamonds', 'Spades'), ('Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Hearts', 'Hearts'), ('Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Hearts', 'Spades'), ('Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Spades', 'Spades'), ('Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs', 'Clubs
# ...

# %% [markdown]
# I believe that the reason Clubs was choosen so much was because it was at the begining of the choices, and it was replaced.

# %% [markdown]
# ###Without Replacement

# %% [markdown]
# There are four different choices, ***Clubs, Diamonds, Hearts, and Spades***, so the equation is going to be:
#
# $$ \frac{4!}{(4-4)!} $$

# %%
print(math.factorial(4))
# Out:
# 24

# %% [markdown]
# There are 24 possibilities without replacement

# %%
from itertools import permutations
print(list(permutations(possibleChoices,4)))
# Out:
# [('Clubs', 'Diamonds', 'Hearts', 'Spades'), ('Clubs', 'Diamonds', 'Spades', 'Hearts'), ('Clubs', 'Hearts', 'Diamonds', 'Spades'), ('Clubs', 'Hearts', 'Spades', 'Diamonds'), ('Clubs', 'Spades', 'Diamonds', 'Hearts'), ('Clubs', 'Spades', 'Hearts', 'Diamonds'), ('Diamonds', 'Clubs', 'Hearts', 'Spades'), ('Diamonds', 'Clubs', 'Spades', 'Hearts'), ('Diamonds', 'Hearts', 'Clubs', 'Spades'), ('Diamonds', 'Hearts', 'Spades', 'Clubs'), ('Diamonds', 'Spades', 'Clubs', 'Hearts'), ('Diamonds', 'Spades', 'Hearts', 'Clubs'), ('Hearts', 'Clubs', 'Diamonds', 'Spades'), ('Hearts', 'Clubs', 'Spades', 'Diamonds'), ('Hearts', 'Diamonds', 'Clubs', 'Spades'), ('Hearts', 'Diamonds', 'Spades', 'Clubs'), ('Hearts', 'Spades', 'Clubs', 'Diamonds'), ('Hearts', 'Spades', 'Diamonds', 'Clubs'), ('Spades', 'Clubs', 'Diamonds', 'Hearts'), ('Spades', 'Clubs', 'Hearts', 'Diamonds'), ('Spades', 'Diamonds', 'Clubs', 'Hearts'), ('Spades', 'Diamonds', 'Hearts', 'Clubs'), ('Spades', 'Hearts', 'Clubs', 'Diamonds'), ('Spades
# ...

# %% [markdown]
# ###Order Doesn't Matter

# %%
from itertools import combinations
print(list(combinations(possibleChoices,4)))
# Out:
# [('Clubs', 'Diamonds', 'Hearts', 'Spades')]

# %% [markdown]
# It gives back the same order as I put in in the begining, even though the order does not matter

# %% [markdown]
# ###(d) What is the coefficent of the 5th order of $(x − 3)^9$?

# %% [markdown]
# The equation is:
#
# $$ \frac{9!}{4!*(9-4)!} = 126$$

# %% [markdown]
# I have discoverd that Combinations and Premutations can be very tricky if you do not pay close attention.
#
# I believe that I was able to code everything, if it is all right is a different story.
#
# The outcomes are all different because each question has different rules, or even has no rules at all, allowing the answers to be all over the board.
