# %% [markdown]
# <a href="https://colab.research.google.com/github/Jake7Harvey/CPSMA/blob/main/ProjectPart_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Module #3: CPSMA-3913-01
# ##Dr Matthew Lynam
# ###Numbers
# ###Jake Harvey 0273045

# %% [markdown]
# ![Pro6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##1. Compute using modulo arithmetic

# %% [markdown]
# ###(a) Convert the number $24036_7$ into base ten

# %% [markdown]
# Converting something into base ten can be tricky, but I have found it easier for me to memorize the power expansion method. With $24036_7$ the equation would be
#
# **$(2 * 7^4) + (4 * 7^3) + (0 * 7^2) + (3 * 7^1) + (6 * 7^0) = 6201$**

# %% [markdown]
# Or you could just code it...

# %%
int('24036',7)
# Out:
# 6201

# %% [markdown]
# ###(b) Convert the hexadecimal number $72e3$ or $0x72e3$ into base ten.

# %% [markdown]
# Looking at this problem, it is very confusing, so I am just going to code it

# %%
int('0x72e3',16)
# Out:
# 29411

# %% [markdown]
# ###(c) Convert 3735928559 into hexadecimal.

# %% [markdown]
# This looks like it's going to be fun, so let's see what kind of coding magic I can do to make it easier

# %%
hex(3735928559)
# Out:
# '0xdeadbeef'

# %% [markdown]
# Honestly, I did not expect the answer to be **0xdeadbeef** so I had to double check it

# %% [markdown]
# ###(d) Using two’s complement preform the base ten subtraction 25 − 37. Check your answer.

# %% [markdown]
# Normaly **25 - 37** would be **-12**, but it's not that easy

# %% [markdown]
# This is the binary form of 25

# %%
bin(25)
# Out:
# '0b11001'

# %% [markdown]
# 0011001

# %% [markdown]
# This is the binary form of -37

# %%
bin(-37)
# Out:
# '-0b100101'

# %% [markdown]
# 11011011

# %% [markdown]
# 0011001 + 11011011 = 11110100

# %%
int(-0b00001100)
# Out:
# -12

# %% [markdown]
# My findings for this week are that binary can be really hard and confusing, and it is very easy to mess up the problem if you are not paying attention.
#
# Computers run off of binary and hexadecimal. Binary allows computers to answer questions like Yes or No, True or False, etc. and hexadecimal shrinks large binary numbers.
