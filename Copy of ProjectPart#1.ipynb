# %% [markdown]
# #Project Part #1: CPSMA-3913-01
# ####Sets
# ####Jake Harvey 0273045

# %% [markdown]
# ##1. Build and manipulate some sets using a programming language.

# %% [markdown]
# A.)
#
#
# ######Casualities of WWII by Counry (ETA)
# ##(A) = {420,000; 380,000; 450,000; 24,000,000; 2,000,000}
# ######Number of Cows by Country (ETA)
# ##(B) = {24,000; 21,600,000; 2,000,000; 980,000; 520,000}
# ######World Population by Country (ETA)
# ##(C) = {380,000; 440,000; 24,000,000; 800; 55,000}

# %% [markdown]
# B.)
# ##U = {752,180; 10,000,000; 40,000; 212,000; 1; 420,000; 380,000; 450,000; 24,000,000; 2,000,000; 24,000; 21,600,000; 2,000,000; 980,000; 520,000; 380,000; 440,000; 24,000,000; 800; 55,000}

# %% [markdown]
# C.)
# ######A u B = {24,000; 380,000; 420,000; 450,000; 520,000; 980,000; 2,000,000; 24,000,000}
# ######A u C = {800; 55,000; 380,000; 420,000; 440,000; 450,000;2,000,000; 24,000,000}
# ######B u C = {800; 24,000; 55,000; 380,000; 440,000; 520,000; 980,000; 2,000,000; 21,600,000; 24,000,000}
# ######A n B = {2,000,000}
# ######A n C = {380,000}
# ######B n C = {NONE}

# %% [markdown]
# D.)
# ###A^c = {752,180; 10,000,000; 40,000; 212,000; 1; 24,000; 21,600,000; 2,000,000; 980,000; 520,000; 440,000; 800; 55,000}
# ###B^c = {752,180; 10,000,000; 40,000; 212,000; 1; 420,000; 380,000; 450,000; 24,000,000; 380,000; 440,000; 24,000,000; 800; 55,000}
# ###C^c ={752,180; 10,000,000; 40,000; 212,000; 1; 420,000; 450,000; 2,000,000; 24,000; 21,600,000; 2,000,000; 980,000; 520,000}

# %% [markdown]
# E.)
# ###A could be a subset of C.

# %% [markdown]
# F.)
# ###Power Set: A = 2^5 = 32
# ###Power Set: U = 2^20 = 1048576

# %% [markdown]
# ##2. Be sure to comment on the following.

# %% [markdown]
# ###A.) I have discoverd that sets are just big patterns, and that once you find the similarities between them they all fit together.

# %% [markdown]
# ###B.) Coding was a bit of a challenge for me. I am new to python, and I am trying to figure it out still. Also it has been a little while since I have used HTML, but I believe that with a little practice I will be able to get back up to speed.
